# %%
boston.data
# Out:
# array([[  6.32000000e-03,   1.80000000e+01,   2.31000000e+00, ...,
#           1.53000000e+01,   3.96900000e+02,   4.98000000e+00],
#        [  2.73100000e-02,   0.00000000e+00,   7.07000000e+00, ...,
#           1.78000000e+01,   3.96900000e+02,   9.14000000e+00],
#        [  2.72900000e-02,   0.00000000e+00,   7.07000000e+00, ...,
#           1.78000000e+01,   3.92830000e+02,   4.03000000e+00],
#        ...,
#        [  6.07600000e-02,   0.00000000e+00,   1.19300000e+01, ...,
#           2.10000000e+01,   3.96900000e+02,   5.64000000e+00],
#        [  1.09590000e-01,   0.00000000e+00,   1.19300000e+01, ...,
#           2.10000000e+01,   3.93450000e+02,   6.48000000e+00],
#        [  4.74100000e-02,   0.00000000e+00,   1.19300000e+01, ...,
#           2.10000000e+01,   3.96900000e+02,   7.88000000e+00]])

# %%
import pandas as pd

fss =pd.read_csv('/home/webadmin/fss_size.csv',sep=';')

# %%
fss
# Out:
#            fss                                FunctionSubSet Name tech  \
# 0   1526726657                              RRC Setup Measurement    L
# 1   1526726659                            E-RAB Setup Measurement    L
# 2   1526726660                          E-RAB Release Measurement    L
# 3   1526726661                    E-RAB Setup Failure Measurement    L
# 4   1526726662                         Cell Algorithm Measurement    L
# 5   1526726664             Throughput and Data Volume Measurement    L
# 6   1526726665                                   PDCP Measurement    L
# 7   1526726666                                 Paging Measurement    L
# 8   1526726683                      RRC Setup Failure Measurement    L
# 9   1526726684                    RRC Reestablishment Measurement    L
# 10  1526726685            RRC Reestablishment Failure Measurement    L
# 11  1526726687                     E-RAB Modification Measurement    L
# 12  1526726690                                    DRB Measurement    L
# 13  1526726693                          Security Mode Measurement    L
# 14  1526726694                                     RA Measurement    L
# 15  1526726698                        Channel Quality Measurement    L
# 16  1526726699                                   MIMO Measurement    L
# 17  1526726700                                    CQI Measurement    L
# 18  1526726701                                    MCS Measurement    L
# 19  1526726702                                    PRB Measurement    L
# 20  1526726704                                    MAC Measurement    L
# 21  1526726705                     Cell User Quantity Measurement    L
# 22  1526726706            Outgoing Inter-RAT Handover Measurement    L
# 23  1526726707            Incoming Inter-RAT Handover Measurement    L
# 24  1526726708            Outgoing Intra-RAT Handover Measurement    L
# 25  1526726709            Incoming Intra-RAT Handover Measurement    L
# 26  1526726710    Outgoing Intra-RAT Handover Measurement over X2    L
# 27  1526726712     Outgoing Intra-RAT Handover Measurement in DRX    L
# 28  1526726722                                 Packet Measurement    L
# 29  1526726724                                   DFEE Measurement    L
# ..         ...                                                ...  ...
# 44  1526726783                       Channel Quality Measurement1    L
# 45  1526726786           UE Traffic Rate Distribution Measurement    L
# 46  1526726787  Throughput and Data Volume Measurement per Pat...    L
# 47  1526726789          Outgoing Inter-RAT Handover Measurement 1    L
# 48  1526726791                 Cell Relay UE Quantity Measurement    L
# 49  1526726804      Differentiated Service Throughput Measurement    L
# 50  1526726805         E-RAB Data Volume Distribution Measurement    L
# 51  1526726807                          Inter-RAT MRO Measurement    L
# 52  1526726808          Outgoing Intra-RAT Handover Measurement 1    L
# 53  1526726812                                  MCS Measurement 1    L
# 54  1526726814                                    MDT Measurement    L
# 55  1526726817                           Extended QCI Measurement    L
# 56  1526726821                                   AMBR Measurement    L
# 57  1526726874                         eMTC RRC Setup Measurement    L
# 58  1526726875                 eMTC RRC Setup Failure Measurement    L
# 59  1526726876                  eMTC UE Context Setup Measurement    L
# 60  1526726877                eMTC UE Context Release Measurement    L
# 61  1526726878          eMTC UE Context Setup Failure Measurement    L
# 62  1526726879                            eMTC Paging Measurement    L
# 63  1526726880                eMTC Cell User Quantity Measurement    L
# 64  1526726890                   eMTC Channel Quality Measurement    L
# 65  1526726891       eMTC Outgoing Intra-RAT Handover Measurement    L
# 66  1526726892       eMTC Incoming Intra-RAT Handover Measurement    L
# 67  1526726893               eMTC RRC Reestablishment Measurement    L
# 68  1526726894       eMTC RRC Reestablishment Failure Measurement    L
# 69  1526726895                               eMTC MAC Measurement    L
# 70  1526726896                        eMTC Repetition Measurement    L
# 71  1526726897                                eMTC RA Measurement    L
# 72  1526726898                               eMTC PRB Measurement    L
# 73  1526726899        eMTC Throughput and Data Volume Measurement    L
#
#       size_mb  Columns
# 0    8.340823       31
# 1   18.581419      118
# 2   35.129652      206
# 3   12.112948       59
# 4   23.365520      176
# 5   34.274716      174
# 6    7.651895       53
# 7    5.053890       10
# 8    5.193357       14
# 9    5.568495       17
# 10   4.460412       11
# 11   6.461928       21
# 12   6.307136       20
# 13   3.866381        4
# 14  10.588893       54
# 15  30.142673      151
# 16  12.585071       92
# 17  10.092357      134
# 18  16.159848      224
# 19  21.901987      148
# 20  31.417142      150
# 21  38.653756      215
# 22  39.040596      216
# 23   4.900521       27
# 24  32.262173      182
# 25   9.964037       63
# 26   8.276894       46
# 27   4.412813       12
# 28  19.883580      112
# 29   3.373115        2
# ..        ...      ...
# 44  21.445810      200
# 45   4.787282       12
# 46  14.433639       60
# 47   3.764918       64
# 48   3.428655        2
# 49   7.980239       33
# 50   9.815621       48
# 51   3.223524        9
# 52   5.823990      108
# 53   7.829110       32
# 54   3.242197        2
# 55   8.766737       60
# 56   4.465697       10
# 57   4.120186        8
# 58   3.095161        1
# 59   3.241580        2
# 60   3.534432        4
# 61   3.095162        1
# 62   3.534436        5
# 63   3.680905        5
# 64   6.023749       21
# 65   3.827335        6
# 66   3.388002        3
# 67   3.241580        2
# 68   3.095161        1
# 69   4.705986       12
# 70   4.413150       10
# 71   4.120100        8
# 72   3.388015        3
# 73   4.705908       12
#
# [74 rows x 5 columns]

# %%
fss
# Out:
#            fss                                FunctionSubSet Name tech  \
# 0   1526726875                 eMTC RRC Setup Failure Measurement    L
# 1   1526726878          eMTC UE Context Setup Failure Measurement    L
# 2   1526726894       eMTC RRC Reestablishment Failure Measurement    L
# 3   1526726724                                   DFEE Measurement    L
# 4   1526726748                       UE Context Setup Measurement    L
# 5   1526726791                 Cell Relay UE Quantity Measurement    L
# 6   1526726814                                    MDT Measurement    L
# 7   1526726876                  eMTC UE Context Setup Measurement    L
# 8   1526726893               eMTC RRC Reestablishment Measurement    L
# 9   1526726726                               Cell LCS Measurement    L
# 10  1526726892       eMTC Incoming Intra-RAT Handover Measurement    L
# 11  1526726898                               eMTC PRB Measurement    L
# 12  1526726693                          Security Mode Measurement    L
# 13  1526726749               UE Context Setup Failure Measurement    L
# 14  1526726877                eMTC UE Context Release Measurement    L
# 15  1526726879                            eMTC Paging Measurement    L
# 16  1526726880                eMTC Cell User Quantity Measurement    L
# 17  1526726891       eMTC Outgoing Intra-RAT Handover Measurement    L
# 18  1526726767                              Cell MBMS Measurement    L
# 19  1526726874                         eMTC RRC Setup Measurement    L
# 20  1526726897                                eMTC RA Measurement    L
# 21  1526726807                          Inter-RAT MRO Measurement    L
# 22  1526726666                                 Paging Measurement    L
# 23  1526726821                                   AMBR Measurement    L
# 24  1526726896                        eMTC Repetition Measurement    L
# 25  1526726685            RRC Reestablishment Failure Measurement    L
# 26  1526726712     Outgoing Intra-RAT Handover Measurement in DRX    L
# 27  1526726786           UE Traffic Rate Distribution Measurement    L
# 28  1526726895                               eMTC MAC Measurement    L
# 29  1526726899        eMTC Throughput and Data Volume Measurement    L
# ..         ...                                                ...  ...
# 44  1526726781                            CA Cell MAC Measurement    L
# 45  1526726805         E-RAB Data Volume Distribution Measurement    L
# 46  1526726782           Throughput and Data Volume Measurement 1    L
# 47  1526726665                                   PDCP Measurement    L
# 48  1526726694                                     RA Measurement    L
# 49  1526726661                    E-RAB Setup Failure Measurement    L
# 50  1526726787  Throughput and Data Volume Measurement per Pat...    L
# 51  1526726817                           Extended QCI Measurement    L
# 52  1526726709            Incoming Intra-RAT Handover Measurement    L
# 53  1526726789          Outgoing Inter-RAT Handover Measurement 1    L
# 54  1526726743                                     CA Measurement    L
# 55  1526726745                  Cell Reserved Counter Measurement    L
# 56  1526726699                                   MIMO Measurement    L
# 57  1526726808          Outgoing Intra-RAT Handover Measurement 1    L
# 58  1526726722                                 Packet Measurement    L
# 59  1526726752                Throughput Distribution Measurement    L
# 60  1526726659                            E-RAB Setup Measurement    L
# 61  1526726700                                    CQI Measurement    L
# 62  1526726702                                    PRB Measurement    L
# 63  1526726704                                    MAC Measurement    L
# 64  1526726698                        Channel Quality Measurement    L
# 65  1526726664             Throughput and Data Volume Measurement    L
# 66  1526726662                         Cell Algorithm Measurement    L
# 67  1526726708            Outgoing Intra-RAT Handover Measurement    L
# 68  1526726764               Packet Size Distribution Measurement    L
# 69  1526726783                       Channel Quality Measurement1    L
# 70  1526726660                          E-RAB Release Measurement    L
# 71  1526726705                     Cell User Quantity Measurement    L
# 72  1526726706            Outgoing Inter-RAT Handover Measurement    L
# 73  1526726701                                    MCS Measurement    L
#
#       size_mb  Columns
# 0    3.095161        1
# 1    3.095162        1
# 2    3.095161        1
# 3    3.373115        2
# 4    3.516430        2
# 5    3.428655        2
# 6    3.242197        2
# 7    3.241580        2
# 8    3.241580        2
# 9    3.373101        2
# 10   3.388002        3
# 11   3.388015        3
# 12   3.866381        4
# 13   3.680990        4
# 14   3.534432        4
# 15   3.534436        4
# 16   3.680905        5
# 17   3.827335        6
# 18   4.211044        7
# 19   4.120186        8
# 20   4.120100        8
# 21   3.223524        1
# 22   5.053890       10
# 23   4.465697       10
# 24   4.413150       10
# 25   4.460412        9
# 26   4.412813        8
# 27   4.787282       12
# 28   4.705986       12
# 29   4.705908       12
# ..        ...      ...
# 44  10.977865       48
# 45   9.815621       48
# 46   4.171711        7
# 47   7.651895       28
# 48  10.588893       42
# 49  12.112948       57
# 50  14.433639       48
# 51   8.766737       60
# 52   9.964037       42
# 53   3.764918        5
# 54   9.548055       37
# 55   4.290595        8
# 56  12.585071       48
# 57   5.823990       17
# 58  19.883580      100
# 59  20.866627      112
# 60  18.581419       94
# 61  10.092357       36
# 62  21.901987       99
# 63  31.417142      138
# 64  30.142673      134
# 65  34.274716      174
# 66  23.365520      118
# 67  32.262173      177
# 68  36.044254      200
# 69  21.445810      100
# 70  35.129652      201
# 71  38.653756      215
# 72  39.040596      218
# 73  16.159848       64
#
# [74 rows x 5 columns]

# %%
len(list(fss['Columns'].values))
# Out:
# 74

# %%
fss['Columns'].values.reshape(-1, 1).shape, fss['size_mb'].values.shape
# Out:
# ((74, 1), (74,))

# %%
lr = linear_model.LinearRegression()
boston = datasets.load_boston()
y = boston.target

# %%
y.shape
# Out:
# (506,)

# %%
predicted
# Out:
# array([  6.60884083,  16.98655336,  27.48354994,   9.94879428,
#         23.90502838,  23.66646027,   9.23308997,   4.10387573,
#          4.58101194,   4.9388641 ,   4.22315978,   5.4160003 ,
#          5.29671625,   3.38817142,   9.35237402,  20.92292707,
#         13.885168  ,  18.89509819,  29.63066288,  20.56507492,
#         20.80364302,  28.55710641,  28.67639046,   6.13170462,
#         24.62073269,  10.42593049,   8.39810161,   4.34244384,
#         16.27084904,   3.14960332,   3.26888737,   5.4160003 ,
#          5.77385246,  11.02235075,   5.65456841,  12.45375938,
#          3.14960332,   2.98788246,   5.2475017 ,  18.24031236,
#         30.6682182 ,   3.41156107,   9.20183538,   9.76674019,
#         30.6682182 ,   4.11769208,  10.89654981,  11.46145462,
#          2.70543005,   7.08344234,   9.20183538,   3.69401347,
#         17.67540754,   6.94221614,   2.70543005,  10.89654981,
#          3.83523967,   3.55278727,   2.56420385,   2.70543005,
#          2.98788246,   2.56420385,   3.12910866,   3.12910866,
#          5.38872791,   3.27033486,   2.84665626,   2.70543005,
#          2.56420385,   4.11769208,   3.83523967,   3.55278727,
#          2.84665626,   4.11769208])

# %%
from sklearn import datasets
from sklearn.model_selection import cross_val_predict
from sklearn import linear_model
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (16,10)
lr = linear_model.LinearRegression()

y=fss['size_mb'].values
# cross_val_predict returns an array of the same size as `y` where each entry
# is a prediction obtained by cross validation:
x= fss['Columns'].values
predicted = cross_val_predict(lr, fss['Columns'].values.reshape(-1, 1), fss['size_mb'].values, cv=2)

fig, ax = plt.subplots()
ax.scatter(x, y, edgecolors=(0, 0, 0))
ax.plot(x, predicted, 'k--', lw=4)
ax.set_xlabel('#Columns')
ax.set_ylabel('File Size (MB)')
plt.grid()
plt.show()

# %%
from sklearn import datasets
from sklearn.model_selection import cross_val_predict
from sklearn import linear_model
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (16,10)
lr = linear_model.LinearRegression()

y=fss['size_mb'].values
# cross_val_predict returns an array of the same size as `y` where each entry
# is a prediction obtained by cross validation:
x= fss['Columns'].values

lr.fit(fss['Columns'].values.reshape(-1, 1),  fss['size_mb'].values)
#predicted = cross_val_predict(lr, fss['Columns'].values.reshape(-1, 1), fss['size_mb'].values, cv=2)
predicted = lr.predict(fss['Columns'].values.reshape(-1, 1))

fig, ax = plt.subplots()
ax.scatter(x, y, edgecolors=(0, 0, 0))
ax.plot(x, predicted, '--', lw=3)
ax.set_xlabel('#Counters',fontsize = 'xx-large')
ax.set_ylabel('File Size (MB)',fontsize = 'xx-large')
plt.title("LTE - Measurement of Cell Performance: File Size Regression",fontsize = 'xx-large')
plt.grid()
plt.show()

# %%
ax.scatter(x, y, edgecolors=(0, 0, 0))

# %%
fss['Columns'].values.reshape(-1, 1)
# Out:
# array([[ 31],
#        [118],
#        [206],
#        [ 59],
#        [176],
#        [174],
#        [ 53],
#        [ 10],
#        [ 14],
#        [ 17],
#        [ 11],
#        [ 21],
#        [ 20],
#        [  4],
#        [ 54],
#        [151],
#        [ 92],
#        [134],
#        [224],
#        [148],
#        [150],
#        [215],
#        [216],
#        [ 27],
#        [182],
#        [ 63],
#        [ 46],
#        [ 12],
#        [112],
#        [  2],
#        [  3],
#        [ 21],
#        [ 24],
#        [ 68],
#        [ 23],
#        [ 80],
#        [  2],
#        [  4],
#        [ 20],
#        [112],
#        [200],
#        [  7],
#        [ 48],
#        [ 52],
#        [200],
#        [ 12],
#        [ 60],
#        [ 64],
#        [  2],
#        [ 33],
#        [ 48],
#        [  9],
#        [108],
#        [ 32],
#        [  2],
#        [ 60],
#        [ 10],
#        [  8],
#        [  1],
#        [  2],
#        [  4],
#        [  1],
#        [  5],
#        [  5],
#        [ 21],
#        [  6],
#        [  3],
#        [  2],
#        [  1],
#        [ 12],
#        [ 10],
#        [  8],
#        [  3],
#        [ 12]])
